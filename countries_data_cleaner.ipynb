# %%
import pandas as pd
import numpy as np
import regex as re

# %%
print("Pandas:",pd.__version__)
print("Numpy:",np.__version__)
print("Regex",re.__version__)
# Out:
# Pandas: 3.0.3
# Numpy: 2.4.6
# Regex 2026.5.9
